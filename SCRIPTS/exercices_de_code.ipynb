# %% [markdown]
# # Premiers exercices

# %%
print("hello")

print("analyse bourse")
# Out:
# hello
# analyse bourse

# %% [markdown]
# # Let's go learning PYTHON

# %%
# Ceci est un commentaire dans la cellule de code 
# Python est une programmation orienté Object. On déf des variables 

name = "Ajla"
name
# Out:
# 'Ajla'

# %%
name = "Thomas"
name
# Out:
# 'Thomas'

# %%
prices = {
    "APPL": 240.04,
    "TSLA": 328.33,
    "GOOGL" : 437.43
}
