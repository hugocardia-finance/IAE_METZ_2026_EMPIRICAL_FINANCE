# %% [markdown]
# # Premiers exercices

# %% [markdown]
# # Let's go learning PYTHON

# %% [markdown]
# # La structure d'un projet python

# %%
import yfinance as yf
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
ticker = "AAPL"

data = yf.download(ticker, start = "2020-01-01", progress = False, auto_adjust=False)

data.head()  # 5 premières ligne 
data.tail()  # 5 dernière ligne
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            AAPL        AAPL        AAPL        AAPL        AAPL
# Date
# 2026-01-26  255.410004  255.410004  256.559998  249.800003  251.479996
# 2026-01-27  258.269989  258.269989  261.950012  258.209991  259.170013
# 2026-01-28  256.440002  256.440002  258.859985  254.509995  257.649994
# 2026-01-29  258.279999  258.279999  259.649994  254.410004  258.000000
# 2026-01-30  259.480011  259.480011  261.899994  252.179993  255.169998
#
# Price         Volume
# Ticker          AAPL
# Date
# 2026-01-26  55969200
# 2026-01-27  49648300
# 2026-01-28  41288000
# 2026-01-29  67253000
# 2026-01-30  92352600

# %%
data["Returns"] = data["Adj Close"].pct_change()

mean_return_daily = data['Returns'].mean()
volatility_daily = data['Returns'].std()

annualized_return = mean_return_daily * 252
annualized_volatility = volatility_daily*np.sqrt(252)
sharpe_ratio = (annualized_return-0.02) / annualized_return

print(f'--- Analyse pour {ticker} ---')
print(f'Rendement Annualisé : {annualized_return}')
print(f'Volatilité Annualisé : {annualized_volatility}')
print(f'Ratio de Sharpe : {sharpe_ratio}')
# Out:
# --- Analyse pour AAPL ---
# Rendement Annualisé : 0.2606026546714986
# Volatilité Annualisé : 0.3168599109482373
# Ratio de Sharpe : 0.9232548109488337

# %%
plt.figure(figsize=(10,6))
plt.plot(data['Close'], label = 'AAPL Closing Price')
plt.plot('Apple stock price over time')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
